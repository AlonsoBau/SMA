# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import numpy as np

# %%
SP = yf.download(tickers='^GSPC', period='max', interval='1d')
SP = SP[['Open', 'Adj Close', 'High', 'Low', 'Volume']]
SP.rename(columns= {'Adj Close': 'Adj_Close'}, inplace=True)
SP = SP.reset_index()
pd.DataFrame.tail(SP)

newcols= ['Date', 'Open', 'Adj_Close', 'High', 'Low', 'Volume']
SP=SP[newcols]
pd.DataFrame(SP)
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Alonso\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#             Date         Open    Adj_Close         High          Low  \
# 0     1927-12-30    17.660000    17.660000    17.660000    17.660000
# 1     1928-01-03    17.760000    17.760000    17.760000    17.760000
# 2     1928-01-04    17.719999    17.719999    17.719999    17.719999
# 3     1928-01-05    17.549999    17.549999    17.549999    17.549999
# 4     1928-01-09    17.500000    17.500000    17.500000    17.500000
# ...          ...          ...          ...          ...          ...
# ...

# %%
MSFT = yf.download(tickers='MSFT', period='max', interval='1d')
MSFT = MSFT[['Open', 'Adj Close', 'High', 'Low', 'Volume']]
MSFT.rename(columns= {'Adj Close': 'Adj_Close'}, inplace=True)
MSFT = MSFT.reset_index()
pd.DataFrame.tail(MSFT)
newcols= ['Date', 'Open', 'Adj_Close', 'High', 'Low', 'Volume']
MSFT=MSFT[newcols]
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Alonso\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
Amazon= yf.download(tickers='AMZN', period='max', interval='1d')
Amazon = Amazon[['Open', 'Adj Close', 'High', 'Low', 'Volume']]
Amazon = Amazon.reset_index()
Amazon.rename(columns= {'Adj Close': 'Adj_Close'}, inplace=True)
Amazon['Date']=pd.to_datetime(Amazon.Date)


newcols= ['Date', 'Open', 'Adj_Close', 'High', 'Low', 'Volume']
Amazon=Amazon[newcols]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Apple= yf.download(tickers='AAPL', period='max', interval='1d')
Apple = Apple[['Open', 'Adj Close', 'High', 'Low', 'Volume']]
Apple= Apple.reset_index()

Apple['Date']= pd.to_datetime(Apple.Date)
Apple.rename(columns= {'Adj Close': 'Adj_Close'}, inplace= True)

newcols= ['Date', 'Open', 'Adj_Close', 'High', 'Low', 'Volume']
Apple=Apple[newcols]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Facebook= yf.download(tickers='FB', period='max', interval='1d')
Facebook.rename(columns={'Adj Close': 'Adj_Close'}, inplace=True)
Facebook= Facebook.reset_index()

Facebook['Date']=pd.to_datetime(Facebook.Date)
pd.DataFrame.head(Facebook)

newcols= ['Date', 'Open', 'Adj_Close', 'High', 'Low', 'Volume']
Facebook=Facebook[newcols]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Google = yf.download(tickers='GOOGL', period='max', interval='1d')
Google = Google[['Open', 'Adj Close', 'High', 'Low', 'Volume']]
Google = Google.reset_index()

Google.rename(columns={'Adj Close': 'Adj_Close'}, inplace=True)
Google['Date']=pd.to_datetime(Google.Date)

newcols= ['Date', 'Open', 'Adj_Close', 'High', 'Low', 'Volume']
Google=Google[newcols]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Netflix = yf.download(tickers='NFLX', period='max', interval='1d')
Netflix = Netflix[['Open', 'Adj Close', 'High', 'Low', 'Volume']]
Netflix = Netflix.reset_index()


Netflix.rename(columns={'Adj Close': 'Adj_Close'}, inplace=True)
Netflix['Date']=pd.to_datetime(Netflix.Date)
pd.DataFrame.head(Netflix)

newcols= ['Date', 'Open', 'Adj_Close', 'High', 'Low', 'Volume']
Netflix=Netflix[newcols]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
SP=SP.groupby(pd.Grouper(key='Date', axis=0,freq='M')).mean()
SP= SP.reset_index()
pd.DataFrame.tail(SP)
# Out:
#            Date         Open    Adj_Close         High          Low  \
# 1122 2021-06-30  4236.976807  4238.489546  4249.386408  4223.202748
# 1123 2021-07-31  4358.000930  4363.712798  4375.644810  4341.074242
# 1124 2021-08-31  4448.834095  4453.965931  4464.497248  4436.474055
# 1125 2021-09-30  4457.234794  4445.543318  4473.472889  4429.424316
# 1126 2021-10-31  4366.534490  4376.649015  4398.789062  4345.891824
#
#             Volume
# 1122  3.895690e+09
# 1123  3.166497e+09
# 1124  2.873544e+09
# 1125  3.155660e+09
# 1126  2.882054e+09

# %%
MSFT=MSFT.groupby(pd.Grouper(key='Date', axis=0,freq='M')).mean()
MSFT= MSFT.reset_index()
pd.DataFrame.tail(MSFT)
# Out:
#           Date        Open   Adj_Close        High         Low        Volume
# 423 2021-06-30  258.318635  258.523263  260.356814  256.875000  2.311692e+07
# 424 2021-07-31  281.022855  280.964501  283.025713  278.994286  2.488899e+07
# 425 2021-08-31  293.608182  294.012759  295.776817  291.877271  2.005714e+07
# 426 2021-09-30  297.950955  296.874284  299.476190  295.102382  2.394700e+07
# 427 2021-10-31  292.315452  294.014546  295.768186  290.520000  2.417000e+07

# %%
Amazon=Amazon.groupby(pd.Grouper(key='Date', axis=0,freq='M')).mean()
Amazon= Amazon.reset_index()
pd.DataFrame.tail(Amazon)
# Out:
#           Date         Open    Adj_Close         High          Low  \
# 289 2021-06-30  3360.013650  3367.725431  3387.670022  3339.960005
# 290 2021-07-31  3612.711437  3616.006185  3647.417132  3575.028076
# 291 2021-08-31  3310.760920  3312.917725  3334.938632  3283.299993
# 292 2021-09-30  3432.441906  3427.182861  3458.274751  3400.572847
# 293 2021-10-31  3273.686346  3275.808216  3302.993630  3248.616388
#
#            Volume
# 289  3.045955e+06
# 290  3.986705e+06
# 291  2.855168e+06
# 292  2.977319e+06
# 293  2.829455e+06

# %%
Apple=Apple.groupby(pd.Grouper(key='Date', axis=0,freq='M')).mean()
Apple= Apple.reset_index()
pd.DataFrame.tail(Apple)
# Out:
#           Date        Open   Adj_Close        High         Low        Volume
# 486 2021-06-30  129.489546  129.764216  130.651819  128.761364  7.302682e+07
# 487 2021-07-31  144.570478  144.922394  146.252383  143.538571  9.137983e+07
# 488 2021-08-31  147.850909  148.137819  149.225909  146.865454  6.639746e+07
# 489 2021-09-30  149.001905  148.306190  149.995239  147.220475  8.559361e+07
# 490 2021-10-31  142.030000  142.265452  143.287272  140.678180  7.559439e+07

# %%
Facebook=Facebook.groupby(pd.Grouper(key='Date', axis=0,freq='M')).mean()
Facebook= Facebook.reset_index()
pd.DataFrame.tail(Facebook)
# Out:
#           Date        Open   Adj_Close        High         Low        Volume
# 109 2021-06-30  335.753636  336.425909  339.281365  332.804090  1.567320e+07
# 110 2021-07-31  352.984288  353.377145  356.978571  349.225237  1.597194e+07
# 111 2021-08-31  361.626823  363.016821  365.617271  359.100908  1.027787e+07
# 112 2021-09-30  365.055713  363.967143  367.679523  360.536189  1.610047e+07
# 113 2021-10-31  330.785450  329.287276  333.108179  325.994548  2.371443e+07

# %%
Google=Google.groupby(pd.Grouper(key='Date', axis=0,freq='M')).mean()
Google= Google.reset_index()

# %%
Netflix=Netflix.groupby(pd.Grouper(key='Date', axis=0,freq='M')).mean()
Netflix= Netflix.reset_index()
pd.DataFrame.head(Netflix)
# Out:
#         Date      Open  Adj_Close      High       Low        Volume
# 0 2002-05-31  1.155833   1.135834  1.175119  1.121429  2.464677e+07
# 1 2002-06-30  1.050214   1.038071  1.084322  1.011929  3.709510e+06
# 2 2002-07-31  1.119578   1.110000  1.154675  1.066429  3.345936e+06
# 3 2002-08-31  0.874805   0.870974  0.902175  0.832890  2.949227e+06
# 4 2002-09-30  0.843179   0.828071  0.858679  0.812786  2.787470e+06

# %%
plt.plot(Amazon.Date, Amazon.Open , label= "Amazon", color="black")
plt.plot(Apple.Date,Apple.Open, label= "Apple", color="lightgray")
plt.plot(Facebook.Date, Facebook.Open , label= "Facebook", color="blue")
plt.plot(Google.Date,Google.Open, label= "Google", color="yellowgreen")
plt.plot(Netflix.Date, Netflix.Open, label="Netflix", color= "red")
plt.plot(MSFT.Date, MSFT.Open, label="MSFT", color= "orange" )
plt.plot(SP.Date, SP.Open, label= "SP", color= "purple")
plt.legend()
plt.title("Open prices with respect to time")
# Out:
# Text(0.5, 1.0, 'Open prices with respect to time')

# %%
TS=pd.to_datetime('2012-05-18')
Amazon = Amazon.loc[Amazon.Date >=TS,:]
Apple = Apple.loc[Apple.Date >= TS, :]
Facebook= Facebook.loc[Facebook.Date >= TS, :]
Google= Google.loc[Google.Date >=TS, :]
Netflix= Netflix.loc[Netflix.Date >=TS, :]
MSFT= MSFT.loc[MSFT.Date >= TS, :]
SP= SP.loc[SP.Date >= TS, :]

# %%
plt.figure(figsize=(15,7))
plt.plot(Amazon.Date, Amazon.Open , label= "Amazon", color="black")
plt.plot(Apple.Date,Apple.Open, label= "Apple", color="lightgray")
plt.plot(Facebook.Date, Facebook.Open , label= "Facebook", color="blue")
plt.plot(Google.Date,Google.Open, label= "Google", color="yellowgreen")
plt.plot(Netflix.Date, Netflix.Open, label="Netflix", color= "red")
plt.plot(MSFT.Date, MSFT.Open, label="MSFT", color= "orange" )
plt.plot(SP.Date, SP.Open, label= "SP", color= "purple")

plt.legend()
plt.title("Open prices with respect to time")
# Out:
# Text(0.5, 1.0, 'Open prices with respect to time')

# %%
plt.figure(figsize=(15,7))
plt.plot(Amazon.Date, Amazon.Adj_Close , label= "Amazon", color="black")
plt.plot(Apple.Date,Apple.Adj_Close, label= "Apple", color="lightgray")
plt.plot(Facebook.Date, Facebook.Adj_Close , label= "Facebook", color="blue")
plt.plot(Google.Date,Google.Adj_Close, label= "Google", color="yellowgreen")
plt.plot(Netflix.Date, Netflix.Adj_Close, label="Netflix", color= "red")
plt.plot(MSFT.Date, MSFT.Adj_Close, label="MSFT", color= "orange" )
plt.plot(SP.Date, SP.Adj_Close, label= "SP", color= "purple")

plt.legend()
plt.title("Adj_Close prices with respect to time")
# Out:
# Text(0.5, 1.0, 'Adj_Close prices with respect to time')

# %%
plt.figure(figsize=(15,7))
plt.plot(Amazon.Date, Amazon.High , label= "Amazon", color="black")
plt.plot(Apple.Date,Apple.High, label= "Apple", color="lightgray")
plt.plot(Facebook.Date, Facebook.High , label= "Facebook", color="blue")
plt.plot(Google.Date,Google.High, label= "Google", color="yellowgreen")
plt.plot(Netflix.Date, Netflix.High, label="Netflix", color= "red")
plt.plot(MSFT.Date, MSFT.High, label="MSFT", color= "orange" )
plt.plot(SP.Date, SP.High, label= "SP", color= "purple")

plt.legend()
plt.title("High prices with respect to time")
# Out:
# Text(0.5, 1.0, 'High prices with respect to time')

# %%
plt.figure(figsize=(15,7))
plt.plot(Amazon.Date, Amazon.Low , label= "Amazon", color="black")
plt.plot(Apple.Date,Apple.Low, label= "Apple", color="lightgray")
plt.plot(Facebook.Date, Facebook.Low , label= "Facebook", color="blue")
plt.plot(Google.Date,Google.Low, label= "Google", color="yellowgreen")
plt.plot(Netflix.Date, Netflix.Low, label="Netflix", color= "red")
plt.plot(MSFT.Date, MSFT.Low, label="MSFT", color= "orange" )
plt.plot(SP.Date, SP.Low, label= "SP", color= "purple")

plt.legend()
plt.title("Low prices with respect to time")
# Out:
# Text(0.5, 1.0, 'Low prices with respect to time')

# %%
plt.figure(figsize=(10,6))
plt.figure(1)
OTCAmazon= Amazon.Open- Amazon.Adj_Close
plt.plot(Amazon.Date, OTCAmazon, color="black")
plt.title('Difference between Open and Adjusted close values in Amazon')

plt.figure(figsize=(10,6))
plt.figure(2)
HtLAmazon= Amazon.High-Amazon.Low
plt.plot(Amazon.Date, HtLAmazon, color="black")
plt.title('Difference between Highest and lowest values in Amazon')

plt.figure(figsize=(10,6))
plt.figure(3)
plt.plot(Amazon.Date, Amazon.Volume, color="black")
plt.title("Volume Amazon as time passes")
# Out:
# Text(0.5, 1.0, 'Volume Amazon as time passes')

# %%
plt.figure(figsize=(10,6))
plt.figure(1)
OTCApple= Apple.Open- Apple.Adj_Close
plt.plot(Apple.Date, OTCApple, color="lightgray")
plt.title('Difference between Open and Adjusted close values in Apple')

plt.figure(figsize=(10,6))
plt.figure(2)
HtLApple= Apple.High-Apple.Low
plt.plot(Apple.Date, HtLApple, color="lightgray")
plt.title('Difference between Highest and lowest values in Apple')

plt.figure(figsize=(10,6))
plt.figure(3)
plt.plot(Apple.Date, Apple.Volume, color="lightgray")
plt.title("Volume Apple as time passes")
# Out:
# Text(0.5, 1.0, 'Volume Apple as time passes')

# %%
plt.figure(figsize=(10,6))
plt.figure(1)
OTCFacebook=Facebook.Open-Facebook.Adj_Close
plt.plot(Facebook.Date, OTCFacebook, color="blue")
plt.title('Difference between Open and Adjusted close values in Facebook')

plt.figure(figsize=(10,6))
plt.figure(2)
HtLFacebook=Facebook.High-Facebook.Low
plt.plot(Facebook.Date, HtLFacebook, color="blue")
plt.title('Difference between Highest and lowest values in Facebook')

plt.figure(figsize=(10,6))
plt.figure(3)
plt.plot(Facebook.Date,Facebook.Volume, color="blue")
plt.title("Volume Facebook as time passes")
# Out:
# Text(0.5, 1.0, 'Volume Facebook as time passes')

# %%
plt.figure(figsize=(10,6))
plt.figure(1)
OTCGoogle=Google.Open-Google.Adj_Close
plt.plot(Google.Date, OTCGoogle, color="yellowgreen")
plt.title('Difference between Open and Adjusted close values in Google')

plt.figure(figsize=(10,6))
plt.figure(2)
HtLGoogle=Google.High-Google.Low
plt.plot(Google.Date, HtLGoogle, color="yellowgreen")
plt.title('Difference between Highest and lowest values in Google')

plt.figure(figsize=(10,6))
plt.figure(3)
plt.plot(Google.Date,Google.Volume, color="yellowgreen")
plt.title("Volume Google as time passes")
# Out:
# Text(0.5, 1.0, 'Volume Google as time passes')

# %%
plt.figure(figsize=(10,6))
plt.figure(1)
OTCNetflix=Netflix.Open-Netflix.Adj_Close
plt.plot(Netflix.Date, OTCNetflix, color="red")
plt.title('Difference between Open and Adjusted close values in Netflix')

plt.figure(figsize=(10,6))
plt.figure(2)
HtLNetflix=Netflix.High-Netflix.Low
plt.plot(Netflix.Date, HtLNetflix, color="red")
plt.title('Difference between Highest and lowest values in Netflix')

plt.figure(figsize=(10,6))
plt.figure(3)
plt.plot(Netflix.Date,Netflix.Volume, color="red")
plt.title("Volume Netflix as time passes")
# Out:
# Text(0.5, 1.0, 'Volume Netflix as time passes')

# %%
plt.figure(figsize=(10,6))
plt.figure(1)
OTCSP=SP.Open-SP.Adj_Close
plt.plot(SP.Date, OTCSP, color="purple")
plt.title('Difference between Open and Adjusted close values in SP')

plt.figure(figsize=(10,6))
plt.figure(2)
HtLSP=SP.High-SP.Low
plt.plot(SP.Date, HtLSP, color="purple")
plt.title('Difference between Highest and lowest values in SP')

plt.figure(figsize=(10,6))
plt.figure(3)
plt.plot(SP.Date,SP.Volume, color="purple")
plt.title("Volume SP as time passes")
# Out:
# Text(0.5, 1.0, 'Volume SP as time passes')

# %%
plt.figure(figsize=(10,6))
plt.figure(1)
OTCMSFT=MSFT.Open-MSFT.Adj_Close
plt.plot(MSFT.Date, OTCMSFT, color="purple")
plt.title('Difference between Open and Adjusted close values in MSFT')

plt.figure(figsize=(10,6))
plt.figure(2)
HtLMSFT=MSFT.High-MSFT.Low
plt.plot(MSFT.Date, HtLMSFT, color="purple")
plt.title('Difference between Highest and lowest values in MSFT')

plt.figure(figsize=(10,6))
plt.figure(3)
plt.plot(MSFT.Date,MSFT.Volume, color="purple")
plt.title("Volume MSFT as time passes")
# Out:
# Text(0.5, 1.0, 'Volume MSFT as time passes')

# %%
#pd.correlation

# %% [markdown]
# Correlation of High Prices:

# %%
cor0=SP['High'].corr(Amazon['High'])
print('Correlation of high prices between SP and Amazon is: ',cor0)

cor1=SP['High'].corr(Apple['High'])
print('Correlation of high prices between SP and Apple is: ',cor1)

cor2=SP['High'].corr(Facebook['High'])
print('Correlation of high prices between SP and Facebook is: ',cor2)

cor3=SP['High'].corr(Google['High'])
print('Correlation of high prices between SP and Google is: ',cor3)

cor4=SP['High'].corr(Netflix['High'])
print('Correlation of high prices between SP and Netflix is: ',cor4)

cor5=SP['High'].corr(MSFT['High'])
print('Correlation of high prices between SP and MSFT is: ',cor5)
# Out:
# Correlation of high prices between SP and Amazon is:  nan
# Correlation of high prices between SP and Apple is:  nan
# Correlation of high prices between SP and Facebook is:  nan
# Correlation of high prices between SP and Google is:  nan
# Correlation of high prices between SP and Netflix is:  nan
# Correlation of high prices between SP and MSFT is:  nan

# %%
cor1=Amazon['High'].corr(Apple['High'])
print('Correlation of high prices between Amazon and Apple is: ',cor1)

cor2=Apple['High'].corr(Facebook['High'])
print('Correlation of high prices between Apple and Facebook is: ',cor2)

cor3=Apple['High'].corr(Google['High'])
print('Correlation of high prices between Apple and Google is: ',cor3)

cor4=Apple['High'].corr(Netflix['High'])
print('Correlation of high prices between Apple and Netflix is: ',cor4)

cor5=Apple['High'].corr(MSFT['High'])
print('Correlation of high prices between Apple and MSFT is: ',cor5)
# Out:
# Correlation of high prices between Amazon and Apple is:  nan
# Correlation of high prices between Apple and Facebook is:  nan
# Correlation of high prices between Apple and Google is:  nan
# Correlation of high prices between Apple and Netflix is:  nan
# Correlation of high prices between Apple and MSFT is:  0.6601774518356841

# %% [markdown]
# Correlation of Low Prices:

# %%
cor0=SP['Low'].corr(Amazon['Low'])
print('Correlation of Low prices between SP and Amazon is: ',cor0)

cor1=SP['Low'].corr(Apple['Low'])
print('Correlation of Low prices between SP and Apple is: ',cor1)

cor2=SP['Low'].corr(Facebook['Low'])
print('Correlation of Low prices between SP and Facebook is: ',cor2)

cor3=SP['Low'].corr(Google['Low'])
print('Correlation of Low prices between SP and Google is: ',cor3)

cor4=SP['Low'].corr(Netflix['Low'])
print('Correlation of Low prices between SP and Netflix is: ',cor4)

cor5=SP['Low'].corr(MSFT['Low'])
print('Correlation of Low prices between SP and MSFT is: ',cor5)
# Out:
# Correlation of Low prices between SP and Amazon is:  nan
# Correlation of Low prices between SP and Apple is:  nan
# Correlation of Low prices between SP and Facebook is:  nan
# Correlation of Low prices between SP and Google is:  nan
# Correlation of Low prices between SP and Netflix is:  nan
# Correlation of Low prices between SP and MSFT is:  nan

# %%
cor1=Amazon['Low'].corr(Apple['Low'])
print('Correlation of Low prices between Amazon and Apple is: ',cor1)

cor2=Apple['Low'].corr(Facebook['Low'])
print('Correlation of Low prices between Apple and Facebook is: ',cor2)

cor3=Apple['Low'].corr(Google['Low'])
print('Correlation of Low prices between Apple and Google is: ',cor3)

cor4=Apple['Low'].corr(Netflix['Low'])
print('Correlation of Low prices between Apple and Netflix is: ',cor4)

cor5=Apple['Low'].corr(MSFT['Low'])
print('Correlation of Low prices between Apple and MSFT is: ',cor5)
# Out:
# Correlation of Low prices between Amazon and Apple is:  nan
# Correlation of Low prices between Apple and Facebook is:  nan
# Correlation of Low prices between Apple and Google is:  nan
# Correlation of Low prices between Apple and Netflix is:  nan
# Correlation of Low prices between Apple and MSFT is:  0.6536485977462333

# %% [markdown]
# Correlation of Volume:

# %%
cor1=Amazon['Volume'].corr(Apple['Volume'])
print('Correlation of Volume prices between Amazon and Apple is: ',cor1)

cor2=Amazon['Volume'].corr(Facebook['Volume'])
print('Correlation of Volume prices between Amazon and Facebook is: ',cor2)

cor3=Amazon['Volume'].corr(Google['Volume'])
print('Correlation of Volume prices between Amazon and Google is: ',cor3)

cor4=Amazon['Volume'].corr(Netflix['Volume'])
print('Correlation of Volume prices between Amazon and Netflix is: ',cor4)
# Out:
# Correlation of Volume prices between Amazon and Apple is:  nan
# Correlation of Volume prices between Amazon and Facebook is:  nan
# Correlation of Volume prices between Amazon and Google is:  -0.11320962094154643
# Correlation of Volume prices between Amazon and Netflix is:  -0.1122755761320249

# %%
cor1=Apple['Volume'].corr(Facebook['Volume'])
print('Correlation of Volume prices between Apple and Facebook is: ',cor1)

cor2=Apple['Volume'].corr(Google['Volume'])
print('Correlation of Volume prices between Apple and Google is: ',cor2)

cor3=Apple['Volume'].corr(Netflix['Volume'])
print('Correlation of Volume prices between Apple and Netflix is: ',cor3)
# Out:
# Correlation of Volume prices between Apple and Facebook is:  nan
# Correlation of Volume prices between Apple and Google is:  nan
# Correlation of Volume prices between Apple and Netflix is:  nan

# %%
cor1=Facebook['Volume'].corr(Google['Volume'])
print('Correlation of Volume prices between Facebook and Google is: ',cor1)

cor2=Facebook['Volume'].corr(Netflix['Volume'])
print('Correlation of Volume prices between Facebook and Netflix is: ',cor2)
# Out:
# Correlation of Volume prices between Facebook and Google is:  0.48838364968993975
# Correlation of Volume prices between Facebook and Netflix is:  nan

# %%
cor1=Google['Volume'].corr(Netflix['Volume'])
print('Correlation of Volume prices between Google and Netflix is: ',cor1)
# Out:
# Correlation of Volume prices between Google and Netflix is:  0.34419290720357765
